# %%
# Compare the validation set errors for different degrees through a plot

fig, ax = plt.subplots(1, 2,  figsize=(16,4))

ax[0].plot(maxtrees, training_acc, label = 'Training', color='#48A9A6')
ax[0].plot(maxtrees, validation_acc, label = 'Validation', color='#C1666B')
ax[0].set_title('Parameter A vs. Accuracy')  
ax[0].set_xlabel('Parameter A')   
ax[0].set_ylabel('Accuracy')
ax[0].legend(loc = 'best')

ax[1].plot(maxtrees, training_acc, label = 'Training', color='#48A9A6')
ax[1].plot(maxtrees, validation_acc, label = 'Validation', color='#C1666B')
ax[1].set_title('Parameter B vs. Accuracy') 
ax[1].set_xlabel('Parameter B')
ax[1].set_ylabel('Accuracy')
ax[1].legend(loc = 'best')

plt.suptitle('Boosting Classifier - Hyperparameter Tuning')
plt.show()
